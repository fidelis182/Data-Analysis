# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/nzovia/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/nzovia/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/nzovia/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /home/nzovia/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /home/nzovia/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('labelled.csv', delimiter=';')

# %%
df.head()
# Out:
#        id                 created_at  \
# 0   77522  2020-04-15 01:03:46+00:00
# 1  661634  2020-06-25 06:20:06+00:00
# 2  413231  2020-06-04 15:41:45+00:00
# 3  760262  2020-07-03 19:39:35+00:00
# 4  830153  2020-07-09 14:39:14+00:00
#
#                                                 text sentiment
# 0  RT @RobertBeadles: Yo💥\nEnter to WIN 1,000 Mon...  positive
# 1  #SriLanka surcharge on fuel removed!\n⛽📉\nThe ...  negative
# 2  Net issuance increases to fund fiscal programs...  positive
# 3  RT @bentboolean: How much of Amazon's traffic ...  positive
# 4  $AMD Ryzen 4000 desktop CPUs looking ‘great’ a...  positive

# %%
pip install clean-text
# Out:
# Requirement already satisfied: clean-text in /home/nzovia/anaconda3/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: emoji<2.0.0,>=1.0.0 in /home/nzovia/anaconda3/lib/python3.11/site-packages (from clean-text) (1.7.0)
# Requirement already satisfied: ftfy<7.0,>=6.0 in /home/nzovia/anaconda3/lib/python3.11/site-packages (from clean-text) (6.1.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/nzovia/anaconda3/lib/python3.11/site-packages (from ftfy<7.0,>=6.0->clean-text) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from cleantext import clean

# %%
# !pip install regex
# Out:
# Requirement already satisfied: regex in /home/nzovia/anaconda3/lib/python3.11/site-packages (2022.7.9)

# %%
import regex as re

# %%
# Define the remove_emojis function (if you haven't defined it yet)

# %%
def remove_emojis(text):
    emoji_pattern = re.compile("[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U00002702-\U000027B0\U000024C2-\U0001F251\U0001F004\U0001F0CF\U0001F170-\U0001F251]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
 # Apply the function to the 'text' column

# %%
df['text'] = df['text'].apply(remove_emojis)

# %%
df.head()
# Out:
#        id                 created_at  \
# 0   77522  2020-04-15 01:03:46+00:00
# 1  661634  2020-06-25 06:20:06+00:00
# 2  413231  2020-06-04 15:41:45+00:00
# 3  760262  2020-07-03 19:39:35+00:00
# 4  830153  2020-07-09 14:39:14+00:00
#
#                                                 text sentiment
# 0  RT @RobertBeadles: Yo\nEnter to WIN 1,000 Mona...  positive
# 1  #SriLanka surcharge on fuel removed!\n\nThe su...  negative
# 2  Net issuance increases to fund fiscal programs...  positive
# 3  RT @bentboolean: How much of Amazon's traffic ...  positive
# 4  $AMD Ryzen 4000 desktop CPUs looking ‘great’ a...  positive

# %%
def remove_user_mentions(text):
      # Define the regular expression pattern to match user mentions
    user_mention_pattern = re.compile(r'@\w+')
     # Replace user mentions with an empty string
    cleaned_text = user_mention_pattern.sub('', text)
    
    return cleaned_text

# %%
# Define a function to username from the text

# %%
df['text'] = df['text'].apply(remove_user_mentions)

# %%
df.head()
# Out:
#        id                 created_at  \
# 0   77522  2020-04-15 01:03:46+00:00
# 1  661634  2020-06-25 06:20:06+00:00
# 2  413231  2020-06-04 15:41:45+00:00
# 3  760262  2020-07-03 19:39:35+00:00
# 4  830153  2020-07-09 14:39:14+00:00
#
#                                                 text sentiment
# 0  RT : Yo\nEnter to WIN 1,000 Monarch Tokens\n\n...  positive
# 1  #SriLanka surcharge on fuel removed!\n\nThe su...  negative
# 2  Net issuance increases to fund fiscal programs...  positive
# 3  RT : How much of Amazon's traffic is served by...  positive
# 4  $AMD Ryzen 4000 desktop CPUs looking ‘great’ a...  positive

# %%
#To remove The #tag from my data

# %%
def remove_hashtags(text):
    # Define the regular expression patterns to match user mentions and hashtags
    hashtag_pattern = re.compile(r'#\w+')
    
    # Replace hashtags with an empty string
    cleaned_text = hashtag_pattern.sub('', text)
    
    return cleaned_text

# %%
df['text'] = df['text'].apply(remove_hashtags)

# %%
df.head()
# Out:
#        id                 created_at  \
# 0   77522  2020-04-15 01:03:46+00:00
# 1  661634  2020-06-25 06:20:06+00:00
# 2  413231  2020-06-04 15:41:45+00:00
# 3  760262  2020-07-03 19:39:35+00:00
# 4  830153  2020-07-09 14:39:14+00:00
#
#                                                 text sentiment
# 0  RT : Yo\nEnter to WIN 1,000 Monarch Tokens\n\n...  positive
# 1   surcharge on fuel removed!\n\nThe surcharge o...  negative
# 2  Net issuance increases to fund fiscal programs...  positive
# 3  RT : How much of Amazon's traffic is served by...  positive
# 4  $AMD Ryzen 4000 desktop CPUs looking ‘great’ a...  positive

# %%
def remove_special_characters(text):
     special_chars_pattern = re.compile(r'[^a-zA-Z0-9\s]')
     return special_chars_pattern.sub('', text)

# %%
df['text'] = df['text'].apply(remove_special_characters)

# %%
df.head()
# Out:
#        id                 created_at  \
# 0   77522  2020-04-15 01:03:46+00:00
# 1  661634  2020-06-25 06:20:06+00:00
# 2  413231  2020-06-04 15:41:45+00:00
# 3  760262  2020-07-03 19:39:35+00:00
# 4  830153  2020-07-09 14:39:14+00:00
#
#                                                 text sentiment
# 0  RT  Yo\nEnter to WIN 1000 Monarch Tokens\n\nUS...  positive
# 1   surcharge on fuel removed\n\nThe surcharge of...  negative
# 2  Net issuance increases to fund fiscal programs...  positive
# 3  RT  How much of Amazons traffic is served by F...  positive
# 4  AMD Ryzen 4000 desktop CPUs looking great and ...  positive

# %%
df1 = pd.read_csv('twitter-stocks (1).csv')

# %%
df.head()
# Out:
#            id                       Date  \
# Index
# 1501   874716  2020-07-13 19:04:37+00:00
# 2586   110418  2020-04-18 19:22:33+00:00
# 2653   888454  2020-07-13 02:54:01+00:00
# 1055   711593  2020-06-30 22:48:16+00:00
# 705    155304  2020-04-22 17:42:14+00:00
#
#                                                     text sentiment
# Index
# 1501   GOOGL GOOG Searches for Chainlink Hits Record ...       NaN
# 2586    We watch NFLX AMZN and  on our ROKU device Pl...       NaN
# 2653   RT  Lol at ES futures Record number of coronav...       NaN
# 1055   RT  SPX SPY Can we close out this quarter alre...  negative
# 705    RT   JNJ AdVac looks like best nearterm prospe...  positive

# %%
df1.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1  2013-11-08  45.930000  46.939999  40.685001  41.650002  41.650002
# 2  2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3  2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4  2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
#
#         Volume
# 0  117701670.0
# 1   27925307.0
# 2   16113941.0
# 3    6316755.0
# 4    8688325.0

# %%
#looking at the dimension of the two data

# %%
df.shape
# Out:
# (5000, 4)

# %%
df1.shape
# Out:
# (2259, 7)

# %%
#To reduce data to 2259 rows

# %%
import numpy as np

# %%
sample_size = 2259
random_sample_df = df.sample(n=sample_size, random_state=42)

# %%
df = random_sample_df

# %%
print(df.shape)
(2259, 4)
# Out:
# (2259, 4)

# %%
df.shape
# Out:
# (2259, 4)

# %%
#naming my first column

# %%
df = df.rename_axis('Index')

# %%
df.head()
# Out:
#            id                                               text sentiment
# Index
# 0      301411  Amedisys Inc AMED COO Christopher Gerard Sells...       NaN
# 1      890123  DIS it could break the 120 pin then 125gt 130 ...       NaN
# 2       62318  RT  Well another point to add to dent the curr...       NaN
# 3      411380  With ad revenues falling whats the impact on s...       NaN
# 4      766908  Your ordinary person would focus on buying pur...       NaN

# %%
df.reset_index(drop=True, inplace=True)

# %%
df = df.rename_axis('Index')

# %%
df.head()
# Out:
#            id                                               text sentiment
# Index
# 0      301411  Amedisys Inc AMED COO Christopher Gerard Sells...       NaN
# 1      890123  DIS it could break the 120 pin then 125gt 130 ...       NaN
# 2       62318  RT  Well another point to add to dent the curr...       NaN
# 3      411380  With ad revenues falling whats the impact on s...       NaN
# 4      766908  Your ordinary person would focus on buying pur...       NaN

# %%
df1 = df1.rename_axis('Index')

# %%
df1.head()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# Index
# 0      2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1      2013-11-08  45.930000  46.939999  40.685001  41.650002  41.650002
# 2      2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3      2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4      2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
#
#             Volume
# Index
# 0      117701670.0
# 1       27925307.0
# 2       16113941.0
# 3        6316755.0
# 4        8688325.0

# %%
# Drop Column created_at

# %%
df.head()
# Out:
#            id                                               text sentiment
# Index
# 0      301411  Amedisys Inc AMED COO Christopher Gerard Sells...       NaN
# 1      890123  DIS it could break the 120 pin then 125gt 130 ...       NaN
# 2       62318  RT  Well another point to add to dent the curr...       NaN
# 3      411380  With ad revenues falling whats the impact on s...       NaN
# 4      766908  Your ordinary person would focus on buying pur...       NaN

# %%
pd.merge(df1, df, on='Index')
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# Index
# 0      2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1      2013-11-08  45.930000  46.939999  40.685001  41.650002  41.650002
# 2      2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3      2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4      2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
# ...           ...        ...        ...        ...        ...        ...
# 2254   2022-10-21  50.000000  50.750000  49.549999  49.889999  49.889999
# 2255   2022-10-24  50.709999  51.860001  50.520000  51.520000  51.520000
# 2256   2022-10-25  52.415001  53.180000  52.200001  52.779999  52.779999
# 2257   2022-10-26  52.950001  53.500000  52.770000  53.349998  53.349998
# 2258   2022-10-27  53.910000  54.000000  53.700001  53.700001  53.700001
#
#             Volume      id                                               text  \
# Index
# 0      117701670.0  301411  Amedisys Inc AMED COO Christopher Gerard Sells...
# 1       27925307.0  890123  DIS it could break the 120 pin then 125gt 130 ...
# 2       16113941.0   62318  RT  Well another point to add to dent the curr...
# 3        6316755.0  411380  With ad revenues falling whats the impact on s...
# 4        8688325.0  766908  Your ordinary person would focus on buying pur...
# ...            ...     ...                                                ...
# 2254    51209029.0  436313  How will the future fly for Spirit Air SAVE   ...
# 2255    22987553.0  313771  RT  The  US New Case data has a 2 day lag but ...
# 2256    35077848.0  392845  RT   has cut the prices of the iPhone 11 range...
# 2257    28064973.0  472959  86369 Million in Sales Expected for Spirit Aer...
# 2258   136345128.0   77522  RT  Yo\nEnter to WIN 1000 Monarch Tokens\n\nUS...
#
#       sentiment
# Index
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2254    neutral
# 2255   negative
# 2256   negative
# 2257   positive
# 2258   positive
#
# [2259 rows x 10 columns]

# %%
print(merged_df.columns)
# Out:
# Index(['Date_left', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'id', 'Date_right', 'text', 'sentiment'],
#       dtype='object')

# %%
pd.merge(df1, df, on='Index', suffixes=('_left', '_right'))
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# Index
# 0      2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1      2013-11-08  45.930000  46.939999  40.685001  41.650002  41.650002
# 2      2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3      2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4      2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
# ...           ...        ...        ...        ...        ...        ...
# 2254   2022-10-21  50.000000  50.750000  49.549999  49.889999  49.889999
# 2255   2022-10-24  50.709999  51.860001  50.520000  51.520000  51.520000
# 2256   2022-10-25  52.415001  53.180000  52.200001  52.779999  52.779999
# 2257   2022-10-26  52.950001  53.500000  52.770000  53.349998  53.349998
# 2258   2022-10-27  53.910000  54.000000  53.700001  53.700001  53.700001
#
#             Volume      id                                               text  \
# Index
# 0      117701670.0  301411  Amedisys Inc AMED COO Christopher Gerard Sells...
# 1       27925307.0  890123  DIS it could break the 120 pin then 125gt 130 ...
# 2       16113941.0   62318  RT  Well another point to add to dent the curr...
# 3        6316755.0  411380  With ad revenues falling whats the impact on s...
# 4        8688325.0  766908  Your ordinary person would focus on buying pur...
# ...            ...     ...                                                ...
# 2254    51209029.0  436313  How will the future fly for Spirit Air SAVE   ...
# 2255    22987553.0  313771  RT  The  US New Case data has a 2 day lag but ...
# 2256    35077848.0  392845  RT   has cut the prices of the iPhone 11 range...
# 2257    28064973.0  472959  86369 Million in Sales Expected for Spirit Aer...
# 2258   136345128.0   77522  RT  Yo\nEnter to WIN 1000 Monarch Tokens\n\nUS...
#
#       sentiment
# Index
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2254    neutral
# 2255   negative
# 2256   negative
# 2257   positive
# 2258   positive
#
# [2259 rows x 10 columns]

# %%
print(merged_df.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'id',
#        'text', 'sentiment'],
#       dtype='object')

# %%
merged_df = merged_df[['Date', 'id', 'text', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'sentiment']]

# %%
merged_df.head()
# Out:
#              Date      id                                               text  \
# Index
# 0      2013-11-07  301411  Amedisys Inc AMED COO Christopher Gerard Sells...
# 1      2013-11-08  890123  DIS it could break the 120 pin then 125gt 130 ...
# 2      2013-11-11   62318  RT  Well another point to add to dent the curr...
# 3      2013-11-12  411380  With ad revenues falling whats the impact on s...
# 4      2013-11-13  766908  Your ordinary person would focus on buying pur...
#
#             Open       High        Low      Close  Adj Close       Volume  \
# Index
# 0      45.099998  50.090000  44.000000  44.900002  44.900002  117701670.0
# 1      45.930000  46.939999  40.685001  41.650002  41.650002   27925307.0
# 2      40.500000  43.000000  39.400002  42.900002  42.900002   16113941.0
# 3      43.660000  43.779999  41.830002  41.900002  41.900002    6316755.0
# 4      41.029999  42.869999  40.759998  42.599998  42.599998    8688325.0
#
#       sentiment
# Index
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
merged_df.to_csv('modified_data.csv', index=False)

# %%
from IPython import display

# %%
display.FileLink('modified_data.csv')
# Out:
# /home/nzovia/Data/modified_data.csv
